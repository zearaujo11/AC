# %% [markdown]
# Dictionary format: {team:[[year, count_players, sum_players_ranking]]}

# %% [markdown]
# ### Dictionary for team average PowerRanking

# %%
import pandas as pd
# Initialize an empty dictionary to store the results
dict_PowerRanking = {}

players = pd.read_csv('players_teams2.csv')

# Iterate through each row in the 'players' DataFrame
for index, row in players.iterrows():
    
    tmID = row['tmID']
    year = row['year']
    playerPowerRanking = row['playerPowerRanking']

    # Check if the team (tmID) is already in the dictionary
    if tmID in dict_PowerRanking:
        # If the year is already present, update the count and sum
        if any(entry[0] == year for entry in dict_PowerRanking[tmID]):
            for entry in dict_PowerRanking[tmID]:
                if entry[0] == year:
                    entry[1] += 1  # Increment count of players
                    entry[2] += playerPowerRanking  # Add playerPowerRanking to sum
        else:
            # If the year is not present, add a new entry
            dict_PowerRanking[tmID].append([year, 1, playerPowerRanking])
    else:
        # If the team is not in the dictionary, add a new entry
        dict_PowerRanking[tmID] = [[year, 1, playerPowerRanking]]

# Print the resulting dictionary
for team, data in dict_PowerRanking.items():
    print(f'Team: {team}')
    for entry in data:
        print(f'Year: {entry[0]}, Count Players: {entry[1]}, Sum Players Performance: {entry[2]}')
    print('---')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-19-13e2cc14d743> in <module>
#       3 dict_PowerRanking = {}
#       4
# ----> 5 players = pd.read_csv('players_teams2.csv')
#       6
#       7 # Iterate through each row in the 'players' DataFrame
#
# c:\Users\anete\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# c:\Users\anete\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# c:\Users\anete\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     948     kwds.update(kwds_defaults)
#     949
# --> 950     return _read(filepath_or_buffer, kwds)
#     951
#     952
#
# c:\Users\anete\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     603
#     604     # Create the parser.
# --> 605     parser = TextFileReader(filepath_or_buffer, **kwds)
#     606
#     607     if chunksize or iterator:
#
# c:\Users\anete\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#    1440
#    1441         self.handles: IOHandles | None = None
# -> 1442         self._engine = self._make_engine(f, self.engine)
#    1443
#    1444     def close(self) -> None:
#
# c:\Users\anete\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, f, engine)
#    1733                 if "b" not in mode:
#    1734                     mode += "b"
# -> 1735             self.handles = get_handle(
#    1736                 f,
#    1737                 mode,
#
# c:\Users\anete\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854         if ioargs.encoding and "b" not in ioargs.mode:
#     855             # Encoding
# --> 856             handle = open(
#     857                 handle,
#     858                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'players_teams2.csv'

# %% [markdown]
# ### Dictionary for team average PER

# %%
# Initialize an empty dictionary to store the results
dict_PER = {}

players = pd.read_csv('players_teams2.csv')

# Iterate through each row in the 'players' DataFrame
for index, row in players.iterrows():
    
    tmID = row['tmID']
    year = row['year']
    playerPowerRanking = row['PER']

    # Check if the team (tmID) is already in the dictionary
    if tmID in dict_PER:
        # If the year is already present, update the count and sum
        if any(entry[0] == year for entry in dict_PER[tmID]):
            for entry in dict_PER[tmID]:
                if entry[0] == year:
                    entry[1] += 1  # Increment count of players
                    entry[2] += playerPowerRanking  # Add playerPowerRanking to sum
        else:
            # If the year is not present, add a new entry
            dict_PER[tmID].append([year, 1, playerPowerRanking])
    else:
        # If the team is not in the dictionary, add a new entry
        dict_PER[tmID] = [[year, 1, playerPowerRanking]]

# Print the resulting dictionary
for team, data in dict_PER.items():
    print(f'Team: {team}')
    for entry in data:
        print(f'Year: {entry[0]}, Count Players: {entry[1]}, Sum Players PER: {entry[2]}')
    print('---')
# Out:
# Team: MIN
# Year: 2, Count Players: 12, Sum Players PER: 101.75268195767244
# Year: 3, Count Players: 12, Sum Players PER: 86.95617754461273
# Year: 4, Count Players: 11, Sum Players PER: 109.37041128693623
# Year: 5, Count Players: 12, Sum Players PER: 107.41078951021024
# Year: 6, Count Players: 15, Sum Players PER: 81.03771961300058
# Year: 7, Count Players: 11, Sum Players PER: 117.70028151468404
# Year: 8, Count Players: 12, Sum Players PER: 116.68360836432076
# Year: 9, Count Players: 15, Sum Players PER: 151.08350957737676
# Year: 10, Count Players: 13, Sum Players PER: 153.82217984599106
# Year: 1, Count Players: 13, Sum Players PER: 115.21141375656724
# ---
# Team: CON
# Year: 9, Count Players: 13, Sum Players PER: 162.25742506086058
# Year: 7, Count Players: 14, Sum Players PER: 165.01758975594518
# Year: 10, Count Players: 14, Sum Players PER: 165.92998106789994
# Year: 4, Count Players: 11, Sum Players PER: 110.77477424077564
# Year: 5, Count Players: 11, Sum Players PER: 118.3890658414859
# Year: 6, Count Players: 12, Sum Players PER: 107.47532985170201
# Year: 8, Count Players: 13, Sum Players PER: 24.69987553118927
# ---
# Team: UTA
# Year: 3, Count Players: 13, Sum Players PER: 141.78162035596665
# Year: 1, Count Players: 14, Sum Players PER: 150.86137918569432
# Year: 2, Count Players: 12, Sum Players PER: 87.17331733009671
# ---
# Team: HOU
# Year: 9, Count Players: 14, Sum Players PER: 102.00029819228033
# Year: 1, Count Players: 12, Sum Players PER: 138.22695361755459
# Year: 2, Count Players: 11, Sum Players PER: 93.78838281041246
# Year: 3, Count Players: 14, Sum Players PER: 115.49029028129564
# Year: 4, Count Players: 12, Sum Players PER: 98.48270986984728
# Year: 6, Count Players: 14, Sum Players PER: 106.52064926852655
# Year: 5, Count Players: 13, Sum Players PER: 92.47107201229086
# Year: 7, Count Players: 13, Sum Players PER: 115.1110373468695
# Year: 8, Count Players: 15, Sum Players PER: 132.80804914021746
# ---
# Team: WAS
# Year: 10, Count Players: 12, Sum Players PER: 111.2660763856744
# Year: 1, Count Players: 13, Sum Players PER: 115.76100655067701
# Year: 2, Count Players: 14, Sum Players PER: 64.43382169178952
# Year: 6, Count Players: 13, Sum Players PER: 120.39687288160019
# Year: 5, Count Players: 12, Sum Players PER: 116.2962929417868
# Year: 7, Count Players: 12, Sum Players PER: 153.45737195897584
# Year: 8, Count Players: 15, Sum Players PER: 147.6370194540606
# Year: 9, Count Players: 16, Sum Players PER: 108.78659751151764
# Year: 3, Count Players: 14, Sum Players PER: 80.88791578537258
# Year: 4, Count Players: 14, Sum Players PER: 120.45369580089947
# ---
# Team: ORL
# Year: 2, Count Players: 12, Sum Players PER: 90.61003746641934
# Year: 3, Count Players: 14, Sum Players PER: 154.87977826734146
# Year: 1, Count Players: 13, Sum Players PER: 120.64617730476434
# ---
# Team: SAC
# Year: 9, Count Players: 13, Sum Players PER: 120.95593888782848
# Year: 3, Count Players: 14, Sum Players PER: 96.5299550726633
# Year: 4, Count Players: 11, Sum Players PER: 106.02947375341583
# Year: 5, Count Players: 12, Sum Players PER: 118.21255128638245
# Year: 8, Count Players: 12, Sum Players PER: 102.8129242782687
# Year: 1, Count Players: 12, Sum Players PER: 130.51775638786853
# Year: 2, Count Players: 13, Sum Players PER: 178.90503519741864
# Year: 10, Count Players: 13, Sum Players PER: 116.2363917373645
# Year: 6, Count Players: 12, Sum Players PER: 112.42222139651406
# Year: 7, Count Players: 10, Sum Players PER: 100.44789215946506
# ---
# Team: NYL
# Year: 2, Count Players: 15, Sum Players PER: 173.03915329845634
# Year: 7, Count Players: 14, Sum Players PER: 116.87604902445294
# Year: 8, Count Players: 14, Sum Players PER: 108.24574783122047
# Year: 4, Count Players: 12, Sum Players PER: 117.12989763556155
# Year: 5, Count Players: 12, Sum Players PER: 107.96002841645277
# Year: 6, Count Players: 15, Sum Players PER: 97.93122358310985
# Year: 9, Count Players: 13, Sum Players PER: 148.18972645981182
# Year: 10, Count Players: 11, Sum Players PER: 122.9949723561287
# Year: 1, Count Players: 13, Sum Players PER: 82.49730945744804
# Year: 3, Count Players: 11, Sum Players PER: 106.07779065538254
# ---
# Team: SEA
# Year: 4, Count Players: 14, Sum Players PER: 110.35287035048106
# Year: 10, Count Players: 13, Sum Players PER: 118.17716226665408
# Year: 1, Count Players: 14, Sum Players PER: 78.54322384679953
# Year: 3, Count Players: 15, Sum Players PER: 135.99294221167867
# Year: 5, Count Players: 12, Sum Players PER: 126.39041848811118
# Year: 2, Count Players: 13, Sum Players PER: 111.49496979438587
# Year: 6, Count Players: 13, Sum Players PER: 118.82326556425362
# Year: 9, Count Players: 14, Sum Players PER: 124.09130511938774
# Year: 7, Count Players: 14, Sum Players PER: 116.12647532110671
# Year: 8, Count Players: 14, Sum Players PER: 105.98608664920566
# ---
# Team: SAS
# Year: 6, Count Players: 12, Sum Players PER: 78.60084026159875
# Year: 7, Count Players: 10, Sum Players PER: 108.08004640574883
# Year: 8, Count Players: 10, Sum Players PER: 104.02307497994585
# Year: 9, Count Players: 12, Sum Players PER: 84.7597380450073
# Year: 4, Count Players: 11, Sum Players PER: 72.22155087354217
# Year: 5, Count Players: 15, Sum Players PER: 175.57025513833403
# Year: 10, Count Players: 9, Sum Players PER: 117.09958512869511
# ---
# Team: CHA
# Year: 2, Count Players: 12, Sum Players PER: 95.88040307028078
# Year: 3, Count Players: 13, Sum Players PER: 149.34063078427977
# Year: 5, Count Players: 14, Sum Players PER: 101.46018454850847
# Year: 1, Count Players: 13, Sum Players PER: 113.43757053097592
# Year: 7, Count Players: 12, Sum Players PER: 124.835976008938
# Year: 4, Count Players: 11, Sum Players PER: 114.49061880929705
# Year: 6, Count Players: 16, Sum Players PER: 114.05335571602419
# ---
# Team: CLE
# Year: 1, Count Players: 13, Sum Players PER: 125.16867894993412
# Year: 2, Count Players: 15, Sum Players PER: 165.3615709542988
# Year: 3, Count Players: 13, Sum Players PER: 97.73036582592205
# Year: 4, Count Players: 11, Sum Players PER: 98.81278119551675
# ---
# Team: MIA
# Year: 1, Count Players: 13, Sum Players PER: 81.21316328942895
# Year: 2, Count Players: 12, Sum Players PER: 79.29361884354887
# Year: 3, Count Players: 15, Sum Players PER: 108.88363993583968
# ---
# Team: LAS
# Year: 3, Count Players: 13, Sum Players PER: 124.85266637634795
# Year: 8, Count Players: 15, Sum Players PER: 99.51219325335789
# Year: 9, Count Players: 15, Sum Players PER: 116.2894037129044
# Year: 10, Count Players: 11, Sum Players PER: 133.42739364218616
# Year: 2, Count Players: 11, Sum Players PER: 139.48375340846516
# Year: 4, Count Players: 15, Sum Players PER: 118.96304088628038
# Year: 5, Count Players: 13, Sum Players PER: 111.60892583442457
# Year: 6, Count Players: 14, Sum Players PER: 105.19502530908439
# Year: 7, Count Players: 14, Sum Players PER: 145.9835932744489
# Year: 1, Count Players: 11, Sum Players PER: 125.8850863718897
# ---
# Team: IND
# Year: 7, Count Players: 12, Sum Players PER: 114.00471136909397
# Year: 4, Count Players: 13, Sum Players PER: 124.92850001126243
# Year: 9, Count Players: 15, Sum Players PER: 126.7290892160193
# Year: 8, Count Players: 12, Sum Players PER: 127.11614899451578
# Year: 6, Count Players: 12, Sum Players PER: 108.55553978823906
# Year: 10, Count Players: 14, Sum Players PER: 176.8053197187938
# Year: 2, Count Players: 13, Sum Players PER: 131.7052488767734
# Year: 5, Count Players: 12, Sum Players PER: 100.82063998721303
# Year: 3, Count Players: 13, Sum Players PER: 110.2549078595571
# Year: 1, Count Players: 15, Sum Players PER: 83.91297165145176
# ---
# Team: DET
# Year: 10, Count Players: 18, Sum Players PER: 160.79742606372665
# Year: 7, Count Players: 13, Sum Players PER: 106.7547254037784
# Year: 2, Count Players: 12, Sum Players PER: 109.02349028441022
# Year: 6, Count Players: 15, Sum Players PER: 123.73373990195239
# Year: 8, Count Players: 14, Sum Players PER: 92.66572456141598
# Year: 9, Count Players: 19, Sum Players PER: 153.32387599111252
# Year: 1, Count Players: 13, Sum Players PER: 156.55581133779918
# Year: 3, Count Players: 15, Sum Players PER: 109.27039077636142
# Year: 5, Count Players: 15, Sum Players PER: 104.9602312387108
# Year: 4, Count Players: 13, Sum Players PER: 128.47602682824052
# ---
# Team: ATL
# Year: 9, Count Players: 14, Sum Players PER: 138.1803816912408
# Year: 10, Count Players: 13, Sum Players PER: 154.24651837237286
# ---
# Team: POR
# Year: 2, Count Players: 13, Sum Players PER: 108.05717087627315
# Year: 3, Count Players: 13, Sum Players PER: 114.61425467302654
# Year: 1, Count Players: 12, Sum Players PER: 97.89163501646244
# ---
# Team: PHO
# Year: 3, Count Players: 15, Sum Players PER: 113.08492856286274
# Year: 10, Count Players: 12, Sum Players PER: 158.69227823126374
# Year: 1, Count Players: 14, Sum Players PER: 129.52324404644904
# Year: 4, Count Players: 21, Sum Players PER: 108.97281660780097
# Year: 5, Count Players: 14, Sum Players PER: 129.12868651255366
# Year: 6, Count Players: 15, Sum Players PER: 152.66232156292318
# Year: 7, Count Players: 16, Sum Players PER: 185.8355746913636
# Year: 2, Count Players: 18, Sum Players PER: 127.4817169723198
# Year: 9, Count Players: 14, Sum Players PER: 157.16347593858973
# Year: 8, Count Players: 13, Sum Players PER: 146.93612136940425
# ---
# Team: CHI
# Year: 7, Count Players: 15, Sum Players PER: 128.06046110300093
# Year: 8, Count Players: 14, Sum Players PER: 137.63151709196288
# Year: 9, Count Players: 13, Sum Players PER: 97.25907152592154
# Year: 10, Count Players: 12, Sum Players PER: 139.85606948192031
# ---

# %% [markdown]
# ### Dictionary for team average Post PowerRanking

# %%
# Initialize an empty dictionary to store the results
dict_postPowerRanking = {}

players = pd.read_csv('players_teams2.csv')

# Iterate through each row in the 'players' DataFrame
for index, row in players.iterrows():
    
    tmID = row['tmID']
    year = row['year']
    playerPowerRanking = row['postPlayerPowerRanking']

    # Check if the team (tmID) is already in the dictionary
    if tmID in dict_postPowerRanking:
        # If the year is already present, update the count and sum
        if any(entry[0] == year for entry in dict_postPowerRanking[tmID]):
            for entry in dict_postPowerRanking[tmID]:
                if entry[0] == year:
                    entry[1] += 1  # Increment count of players
                    entry[2] += playerPowerRanking  # Add playerPowerRanking to sum
        else:
            # If the year is not present, add a new entry
            dict_postPowerRanking[tmID].append([year, 1, playerPowerRanking])
    else:
        # If the team is not in the dictionary, add a new entry
        dict_postPowerRanking[tmID] = [[year, 1, playerPowerRanking]]

# Print the resulting dictionary
for team, data in dict_postPowerRanking.items():
    print(f'Team: {team}')
    for entry in data:
        print(f'Year: {entry[0]}, Count Players: {entry[1]}, Sum Players post PowerRanking: {entry[2]}')
    print('---')
# Out:
# Team: MIN
# Year: 2, Count Players: 12, Sum Players post PowerRanking: 0.0
# Year: 3, Count Players: 12, Sum Players post PowerRanking: 0.0
# Year: 4, Count Players: 11, Sum Players post PowerRanking: 194.62506483802582
# Year: 5, Count Players: 12, Sum Players post PowerRanking: 167.91884917239025
# Year: 6, Count Players: 15, Sum Players post PowerRanking: 0.0
# Year: 7, Count Players: 11, Sum Players post PowerRanking: 0.0
# Year: 8, Count Players: 12, Sum Players post PowerRanking: 0.0
# Year: 9, Count Players: 15, Sum Players post PowerRanking: 0.0
# Year: 10, Count Players: 13, Sum Players post PowerRanking: 0.0
# Year: 1, Count Players: 13, Sum Players post PowerRanking: 0.0
# ---
# Team: CON
# Year: 9, Count Players: 13, Sum Players post PowerRanking: 220.99854090857423
# Year: 7, Count Players: 14, Sum Players post PowerRanking: 265.3603873507785
# Year: 10, Count Players: 14, Sum Players post PowerRanking: 0.0
# Year: 4, Count Players: 11, Sum Players post PowerRanking: 251.19056805594298
# Year: 5, Count Players: 11, Sum Players post PowerRanking: 284.44390214329616
# Year: 6, Count Players: 12, Sum Players post PowerRanking: 294.4358242134367
# Year: 8, Count Players: 13, Sum Players post PowerRanking: 278.6645857257068
# ---
# Team: UTA
# Year: 3, Count Players: 13, Sum Players post PowerRanking: 278.6375427300083
# Year: 1, Count Players: 14, Sum Players post PowerRanking: 0.0
# Year: 2, Count Players: 12, Sum Players post PowerRanking: 176.98562699118548
# ---
# Team: HOU
# Year: 9, Count Players: 14, Sum Players post PowerRanking: 0.0
# Year: 1, Count Players: 12, Sum Players post PowerRanking: 268.36306542189556
# Year: 2, Count Players: 11, Sum Players post PowerRanking: 206.1074038132066
# Year: 3, Count Players: 14, Sum Players post PowerRanking: 236.53812096697703
# Year: 4, Count Players: 12, Sum Players post PowerRanking: 219.6096106945255
# Year: 6, Count Players: 14, Sum Players post PowerRanking: 258.3379960704441
# Year: 5, Count Players: 13, Sum Players post PowerRanking: 0.0
# Year: 7, Count Players: 13, Sum Players post PowerRanking: 225.6384667794712
# Year: 8, Count Players: 15, Sum Players post PowerRanking: 0.0
# ---
# Team: WAS
# Year: 10, Count Players: 12, Sum Players post PowerRanking: 187.1641571786922
# Year: 1, Count Players: 13, Sum Players post PowerRanking: 195.9731109172227
# Year: 2, Count Players: 14, Sum Players post PowerRanking: 0.0
# Year: 6, Count Players: 13, Sum Players post PowerRanking: 0.0
# Year: 5, Count Players: 12, Sum Players post PowerRanking: 239.64074694155698
# Year: 7, Count Players: 12, Sum Players post PowerRanking: 174.5075091575632
# Year: 8, Count Players: 15, Sum Players post PowerRanking: 0.0
# Year: 9, Count Players: 16, Sum Players post PowerRanking: 0.0
# Year: 3, Count Players: 14, Sum Players post PowerRanking: 279.0362786325092
# Year: 4, Count Players: 14, Sum Players post PowerRanking: 0.0
# ---
# Team: ORL
# Year: 2, Count Players: 12, Sum Players post PowerRanking: 0.0
# Year: 3, Count Players: 14, Sum Players post PowerRanking: 0.0
# Year: 1, Count Players: 13, Sum Players post PowerRanking: 207.70824286447925
# ---
# Team: SAC
# Year: 9, Count Players: 13, Sum Players post PowerRanking: 243.71281444152717
# Year: 3, Count Players: 14, Sum Players post PowerRanking: 0.0
# Year: 4, Count Players: 11, Sum Players post PowerRanking: 261.40784460415375
# Year: 5, Count Players: 12, Sum Players post PowerRanking: 265.6968743316536
# Year: 8, Count Players: 12, Sum Players post PowerRanking: 256.9016320500186
# Year: 1, Count Players: 12, Sum Players post PowerRanking: 215.6220499326687
# Year: 2, Count Players: 13, Sum Players post PowerRanking: 277.8100398342234
# Year: 10, Count Players: 13, Sum Players post PowerRanking: 0.0
# Year: 6, Count Players: 12, Sum Players post PowerRanking: 297.5696745322092
# Year: 7, Count Players: 10, Sum Players post PowerRanking: 285.22735243283694
# ---
# Team: NYL
# Year: 2, Count Players: 15, Sum Players post PowerRanking: 242.89476595678082
# Year: 7, Count Players: 14, Sum Players post PowerRanking: 0.0
# Year: 8, Count Players: 14, Sum Players post PowerRanking: 242.89946499896004
# Year: 4, Count Players: 12, Sum Players post PowerRanking: 0.0
# Year: 5, Count Players: 12, Sum Players post PowerRanking: 257.940335514202
# Year: 6, Count Players: 15, Sum Players post PowerRanking: 157.34800013559482
# Year: 9, Count Players: 13, Sum Players post PowerRanking: 277.038561472066
# Year: 10, Count Players: 11, Sum Players post PowerRanking: 0.0
# Year: 1, Count Players: 13, Sum Players post PowerRanking: 298.4245116924518
# Year: 3, Count Players: 11, Sum Players post PowerRanking: 308.459228738035
# ---
# Team: SEA
# Year: 4, Count Players: 14, Sum Players post PowerRanking: 0.0
# Year: 10, Count Players: 13, Sum Players post PowerRanking: 211.01603686067466
# Year: 1, Count Players: 14, Sum Players post PowerRanking: 0.0
# Year: 3, Count Players: 15, Sum Players post PowerRanking: 222.26471793936813
# Year: 5, Count Players: 12, Sum Players post PowerRanking: 314.09594468356136
# Year: 2, Count Players: 13, Sum Players post PowerRanking: 0.0
# Year: 6, Count Players: 13, Sum Players post PowerRanking: 245.12226049338707
# Year: 9, Count Players: 14, Sum Players post PowerRanking: 226.9494261683197
# Year: 7, Count Players: 14, Sum Players post PowerRanking: 223.22375474783556
# Year: 8, Count Players: 14, Sum Players post PowerRanking: 200.35980676366088
# ---
# Team: SAS
# Year: 6, Count Players: 12, Sum Players post PowerRanking: 0.0
# Year: 7, Count Players: 10, Sum Players post PowerRanking: 0.0
# Year: 8, Count Players: 10, Sum Players post PowerRanking: 273.00822828766366
# Year: 9, Count Players: 12, Sum Players post PowerRanking: 268.55325828292024
# Year: 4, Count Players: 11, Sum Players post PowerRanking: 0.0
# Year: 5, Count Players: 15, Sum Players post PowerRanking: 0.0
# Year: 10, Count Players: 9, Sum Players post PowerRanking: 235.19311496316442
# ---
# Team: CHA
# Year: 2, Count Players: 12, Sum Players post PowerRanking: 293.3965777450302
# Year: 3, Count Players: 13, Sum Players post PowerRanking: 203.3736448457919
# Year: 5, Count Players: 14, Sum Players post PowerRanking: 0.0
# Year: 1, Count Players: 13, Sum Players post PowerRanking: 0.0
# Year: 7, Count Players: 12, Sum Players post PowerRanking: 0.0
# Year: 4, Count Players: 11, Sum Players post PowerRanking: 187.75476971763214
# Year: 6, Count Players: 16, Sum Players post PowerRanking: 0.0
# ---
# Team: CLE
# Year: 1, Count Players: 13, Sum Players post PowerRanking: 273.5358258016392
# Year: 2, Count Players: 15, Sum Players post PowerRanking: 240.9526734095133
# Year: 3, Count Players: 13, Sum Players post PowerRanking: 0.0
# Year: 4, Count Players: 11, Sum Players post PowerRanking: 247.9887331539666
# ---
# Team: MIA
# Year: 1, Count Players: 13, Sum Players post PowerRanking: 0.0
# Year: 2, Count Players: 12, Sum Players post PowerRanking: 207.1802121821057
# Year: 3, Count Players: 15, Sum Players post PowerRanking: 0.0
# ---
# Team: LAS
# Year: 3, Count Players: 13, Sum Players post PowerRanking: 308.8606450888581
# Year: 8, Count Players: 15, Sum Players post PowerRanking: 0.0
# Year: 9, Count Players: 15, Sum Players post PowerRanking: 303.1862481081038
# Year: 10, Count Players: 11, Sum Players post PowerRanking: 273.39496068893914
# Year: 2, Count Players: 11, Sum Players post PowerRanking: 304.39753299947563
# Year: 4, Count Players: 15, Sum Players post PowerRanking: 307.62570649427124
# Year: 5, Count Players: 13, Sum Players post PowerRanking: 223.59537242554936
# Year: 6, Count Players: 14, Sum Players post PowerRanking: 256.01568695563617
# Year: 7, Count Players: 14, Sum Players post PowerRanking: 280.7884440397974
# Year: 1, Count Players: 11, Sum Players post PowerRanking: 274.2749359892799
# ---
# Team: IND
# Year: 7, Count Players: 12, Sum Players post PowerRanking: 108.30360479233553
# Year: 4, Count Players: 13, Sum Players post PowerRanking: 0.0
# Year: 9, Count Players: 15, Sum Players post PowerRanking: 250.2987765072136
# Year: 8, Count Players: 12, Sum Players post PowerRanking: 278.9043999547905
# Year: 6, Count Players: 12, Sum Players post PowerRanking: 221.92671390810776
# Year: 10, Count Players: 14, Sum Players post PowerRanking: 331.73625432317436
# Year: 2, Count Players: 13, Sum Players post PowerRanking: 0.0
# Year: 5, Count Players: 12, Sum Players post PowerRanking: 0.0
# Year: 3, Count Players: 13, Sum Players post PowerRanking: 214.36598457367097
# Year: 1, Count Players: 15, Sum Players post PowerRanking: 0.0
# ---
# Team: DET
# Year: 10, Count Players: 18, Sum Players post PowerRanking: 265.3086296114102
# Year: 7, Count Players: 13, Sum Players post PowerRanking: 300.97651542982794
# Year: 2, Count Players: 12, Sum Players post PowerRanking: 0.0
# Year: 6, Count Players: 15, Sum Players post PowerRanking: 142.8920320480065
# Year: 8, Count Players: 14, Sum Players post PowerRanking: 311.65619075875804
# Year: 9, Count Players: 19, Sum Players post PowerRanking: 309.2535556819562
# Year: 1, Count Players: 13, Sum Players post PowerRanking: 0.0
# Year: 3, Count Players: 15, Sum Players post PowerRanking: 0.0
# Year: 5, Count Players: 15, Sum Players post PowerRanking: 236.88508681535336
# Year: 4, Count Players: 13, Sum Players post PowerRanking: 297.3716906202843
# ---
# Team: ATL
# Year: 9, Count Players: 14, Sum Players post PowerRanking: 0.0
# Year: 10, Count Players: 13, Sum Players post PowerRanking: 243.95962650691288
# ---
# Team: POR
# Year: 2, Count Players: 13, Sum Players post PowerRanking: 0.0
# Year: 3, Count Players: 13, Sum Players post PowerRanking: 0.0
# Year: 1, Count Players: 12, Sum Players post PowerRanking: 0.0
# ---
# Team: PHO
# Year: 3, Count Players: 15, Sum Players post PowerRanking: 0.0
# Year: 10, Count Players: 12, Sum Players post PowerRanking: 332.0264579507498
# Year: 1, Count Players: 14, Sum Players post PowerRanking: 225.40047497863446
# Year: 4, Count Players: 21, Sum Players post PowerRanking: 0.0
# Year: 5, Count Players: 14, Sum Players post PowerRanking: 0.0
# Year: 6, Count Players: 15, Sum Players post PowerRanking: 0.0
# Year: 7, Count Players: 16, Sum Players post PowerRanking: 0.0
# Year: 2, Count Players: 18, Sum Players post PowerRanking: 0.0
# Year: 9, Count Players: 14, Sum Players post PowerRanking: 0.0
# Year: 8, Count Players: 13, Sum Players post PowerRanking: 316.30973512110364
# ---
# Team: CHI
# Year: 7, Count Players: 15, Sum Players post PowerRanking: 0.0
# Year: 8, Count Players: 14, Sum Players post PowerRanking: 0.0
# Year: 9, Count Players: 13, Sum Players post PowerRanking: 0.0
# Year: 10, Count Players: 12, Sum Players post PowerRanking: 0.0
# ---

# %% [markdown]
# ### Dictionary for team average Post PER

# %%
# Initialize an empty dictionary to store the results
dict_postPER = {}

players = pd.read_csv('players_teams2.csv')

# Iterate through each row in the 'players' DataFrame
for index, row in players.iterrows():
    
    tmID = row['tmID']
    year = row['year']
    playerPowerRanking = row['postPER']

    # Check if the team (tmID) is already in the dictionary
    if tmID in dict_postPER:
        # If the year is already present, update the count and sum
        if any(entry[0] == year for entry in dict_postPER[tmID]):
            for entry in dict_postPER[tmID]:
                if entry[0] == year:
                    entry[1] += 1  # Increment count of players
                    entry[2] += playerPowerRanking  # Add playerPowerRanking to sum
        else:
            # If the year is not present, add a new entry
            dict_postPER[tmID].append([year, 1, playerPowerRanking])
    else:
        # If the team is not in the dictionary, add a new entry
        dict_postPER[tmID] = [[year, 1, playerPowerRanking]]

print(dict_postPowerRanking)
# Print the resulting dictionary
for team, data in dict_postPER.items():
    print(f'Team: {team}')
    for entry in data:
        print(f'Year: {entry[0]}, Count Players: {entry[1]}, Sum Players post PER: {entry[2]}')
    print('---')
# Out:
# {'MIN': [[2, 12, 0.0], [3, 12, 0.0], [4, 11, 194.62506483802582], [5, 12, 167.91884917239025], [6, 15, 0.0], [7, 11, 0.0], [8, 12, 0.0], [9, 15, 0.0], [10, 13, 0.0], [1, 13, 0.0]], 'CON': [[9, 13, 220.99854090857423], [7, 14, 265.3603873507785], [10, 14, 0.0], [4, 11, 251.19056805594298], [5, 11, 284.44390214329616], [6, 12, 294.4358242134367], [8, 13, 278.6645857257068]], 'UTA': [[3, 13, 278.6375427300083], [1, 14, 0.0], [2, 12, 176.98562699118548]], 'HOU': [[9, 14, 0.0], [1, 12, 268.36306542189556], [2, 11, 206.1074038132066], [3, 14, 236.53812096697703], [4, 12, 219.6096106945255], [6, 14, 258.3379960704441], [5, 13, 0.0], [7, 13, 225.6384667794712], [8, 15, 0.0]], 'WAS': [[10, 12, 187.1641571786922], [1, 13, 195.9731109172227], [2, 14, 0.0], [6, 13, 0.0], [5, 12, 239.64074694155698], [7, 12, 174.5075091575632], [8, 15, 0.0], [9, 16, 0.0], [3, 14, 279.0362786325092], [4, 14, 0.0]], 'ORL': [[2, 12, 0.0], [3, 14, 0.0], [1, 13, 207.70824286447925]], 'SAC': [[9, 13, 243.71281444152717], [3, 14, 0.0], [4, 11, 261.40784460415375], [5, 12, 265.6968743316536], [8, 12, 256.9016320500186], [1, 12, 215.6220499326687], [2, 13, 277.8100398342234], [10, 13, 0.0], [6, 12, 297.5696745322092], [7, 10, 285.22735243283694]], 'NYL': [[2, 15, 242.89476595678082], [7, 14, 0.0], [8, 14, 242.89946499896004], [4, 12, 0.0], [5, 12, 257.940335514202], [6, 15, 157.34800013559482], [9, 13, 277.038561472066], [10, 11, 0.0], [1, 13, 298.4245116924518], [3, 11, 308.459228738035]], 'SEA': [[4, 14, 0.0], [10, 13, 211.01603686067466], [1, 14, 0.0], [3, 15, 222.26471793936813], [5, 12, 314.09594468356136], [2, 13, 0.0], [6, 13, 245.12226049338707], [9, 14, 226.9494261683197], [7, 14, 223.22375474783556], [8, 14, 200.35980676366088]], 'SAS': [[6, 12, 0.0], [7, 10, 0.0], [8, 10, 273.00822828766366], [9, 12, 268.55325828292024], [4, 11, 0.0], [5, 15, 0.0], [10, 9, 235.19311496316442]], 'CHA': [[2, 12, 293.3965777450302], [3, 13, 203.3736448457919], [5, 14, 0.0], [1, 13, 0.0], [7, 12, 0.0], [4, 11, 187.75476971763214], [6, 16, 0.0]], 'CLE': [[1, 13, 273.5358258016392], [2, 15, 240.9526734095133], [3, 13, 0.0], [4, 11, 247.9887331539666]], 'MIA': [[1, 13, 0.0], [2, 12, 207.1802121821057], [3, 15, 0.0]], 'LAS': [[3, 13, 308.8606450888581], [8, 15, 0.0], [9, 15, 303.1862481081038], [10, 11, 273.39496068893914], [2, 11, 304.39753299947563], [4, 15, 307.62570649427124], [5, 13, 223.59537242554936], [6, 14, 256.01568695563617], [7, 14, 280.7884440397974], [1, 11, 274.2749359892799]], 'IND': [[7, 12, 108.30360479233553], [4, 13, 0.0], [9, 15, 250.2987765072136], [8, 12, 278.9043999547905], [6, 12, 221.92671390810776], [10, 14, 331.73625432317436], [2, 13, 0.0], [5, 12, 0.0], [3, 13, 214.36598457367097], [1, 15, 0.0]], 'DET': [[10, 18, 265.3086296114102], [7, 13, 300.97651542982794], [2, 12, 0.0], [6, 15, 142.8920320480065], [8, 14, 311.65619075875804], [9, 19, 309.2535556819562], [1, 13, 0.0], [3, 15, 0.0], [5, 15, 236.88508681535336], [4, 13, 297.3716906202843]], 'ATL': [[9, 14, 0.0], [10, 13, 243.95962650691288]], 'POR': [[2, 13, 0.0], [3, 13, 0.0], [1, 12, 0.0]], 'PHO': [[3, 15, 0.0], [10, 12, 332.0264579507498], [1, 14, 225.40047497863446], [4, 21, 0.0], [5, 14, 0.0], [6, 15, 0.0], [7, 16, 0.0], [2, 18, 0.0], [9, 14, 0.0], [8, 13, 316.30973512110364]], 'CHI': [[7, 15, 0.0], [8, 14, 0.0], [9, 13, 0.0], [10, 12, 0.0]]}
# Team: MIN
# Year: 2, Count Players: 12, Sum Players post PER: 0.0
# Year: 3, Count Players: 12, Sum Players post PER: 0.0
# Year: 4, Count Players: 11, Sum Players post PER: 57.617239073974034
# Year: 5, Count Players: 12, Sum Players post PER: -93.1339179654959
# Year: 6, Count Players: 15, Sum Players post PER: 0.0
# Year: 7, Count Players: 11, Sum Players post PER: 0.0
# Year: 8, Count Players: 12, Sum Players post PER: 0.0
# Year: 9, Count Players: 15, Sum Players post PER: 0.0
# Year: 10, Count Players: 13, Sum Players post PER: 0.0
# Year: 1, Count Players: 13, Sum Players post PER: 0.0
# ---
# Team: CON
# Year: 9, Count Players: 13, Sum Players post PER: 79.63355988176019
# Year: 7, Count Players: 14, Sum Players post PER: 85.63623181191085
# Year: 10, Count Players: 14, Sum Players post PER: 0.0
# Year: 4, Count Players: 11, Sum Players post PER: 125.00772432768298
# Year: 5, Count Players: 11, Sum Players post PER: 115.54312419460251
# Year: 6, Count Players: 12, Sum Players post PER: 87.98804016822248
# Year: 8, Count Players: 13, Sum Players post PER: 119.09711474875651
# ---
# Team: UTA
# Year: 3, Count Players: 13, Sum Players post PER: 137.2369088750101
# Year: 1, Count Players: 14, Sum Players post PER: 0.0
# Year: 2, Count Players: 12, Sum Players post PER: 108.01439911475673
# ---
# Team: HOU
# Year: 9, Count Players: 14, Sum Players post PER: 0.0
# Year: 1, Count Players: 12, Sum Players post PER: 82.78580763642631
# Year: 2, Count Players: 11, Sum Players post PER: 69.88416736380034
# Year: 3, Count Players: 14, Sum Players post PER: 82.75345385604572
# Year: 4, Count Players: 12, Sum Players post PER: 28.410792455906552
# Year: 6, Count Players: 14, Sum Players post PER: 163.24135200291195
# Year: 5, Count Players: 13, Sum Players post PER: 0.0
# Year: 7, Count Players: 13, Sum Players post PER: 92.69498066197384
# Year: 8, Count Players: 15, Sum Players post PER: 0.0
# ---
# Team: WAS
# Year: 10, Count Players: 12, Sum Players post PER: 93.24173161433804
# Year: 1, Count Players: 13, Sum Players post PER: 53.763350226605674
# Year: 2, Count Players: 14, Sum Players post PER: 0.0
# Year: 6, Count Players: 13, Sum Players post PER: 0.0
# Year: 5, Count Players: 12, Sum Players post PER: 98.58160256353985
# Year: 7, Count Players: 12, Sum Players post PER: 53.194299510408044
# Year: 8, Count Players: 15, Sum Players post PER: 0.0
# Year: 9, Count Players: 16, Sum Players post PER: 0.0
# Year: 3, Count Players: 14, Sum Players post PER: 128.31361272944937
# Year: 4, Count Players: 14, Sum Players post PER: 0.0
# ---
# Team: ORL
# Year: 2, Count Players: 12, Sum Players post PER: 0.0
# Year: 3, Count Players: 14, Sum Players post PER: 0.0
# Year: 1, Count Players: 13, Sum Players post PER: 61.68555676375632
# ---
# Team: SAC
# Year: 9, Count Players: 13, Sum Players post PER: 76.05219384926076
# Year: 3, Count Players: 14, Sum Players post PER: 0.0
# Year: 4, Count Players: 11, Sum Players post PER: 53.853375235761675
# Year: 5, Count Players: 12, Sum Players post PER: 77.02534694184632
# Year: 8, Count Players: 12, Sum Players post PER: 95.73168278357232
# Year: 1, Count Players: 12, Sum Players post PER: 124.3260602909986
# Year: 2, Count Players: 13, Sum Players post PER: 136.78373486441558
# Year: 10, Count Players: 13, Sum Players post PER: 0.0
# Year: 6, Count Players: 12, Sum Players post PER: 107.9862440743883
# Year: 7, Count Players: 10, Sum Players post PER: 110.09350289966214
# ---
# Team: NYL
# Year: 2, Count Players: 15, Sum Players post PER: -12.095630191140323
# Year: 7, Count Players: 14, Sum Players post PER: 0.0
# Year: 8, Count Players: 14, Sum Players post PER: 60.51468501968158
# Year: 4, Count Players: 12, Sum Players post PER: 0.0
# Year: 5, Count Players: 12, Sum Players post PER: 132.7107071298859
# Year: 6, Count Players: 15, Sum Players post PER: 37.94536946020145
# Year: 9, Count Players: 13, Sum Players post PER: 97.66014502968038
# Year: 10, Count Players: 11, Sum Players post PER: 0.0
# Year: 1, Count Players: 13, Sum Players post PER: 150.27367050817818
# Year: 3, Count Players: 11, Sum Players post PER: 122.70776538123198
# ---
# Team: SEA
# Year: 4, Count Players: 14, Sum Players post PER: 0.0
# Year: 10, Count Players: 13, Sum Players post PER: -7.728878739048305
# Year: 1, Count Players: 14, Sum Players post PER: 0.0
# Year: 3, Count Players: 15, Sum Players post PER: 61.134251181690864
# Year: 5, Count Players: 12, Sum Players post PER: 126.11619027200088
# Year: 2, Count Players: 13, Sum Players post PER: 0.0
# Year: 6, Count Players: 13, Sum Players post PER: 64.29454478485984
# Year: 9, Count Players: 14, Sum Players post PER: 80.25783338602761
# Year: 7, Count Players: 14, Sum Players post PER: 63.21058934981859
# Year: 8, Count Players: 14, Sum Players post PER: 103.91422511297685
# ---
# Team: SAS
# Year: 6, Count Players: 12, Sum Players post PER: 0.0
# Year: 7, Count Players: 10, Sum Players post PER: 0.0
# Year: 8, Count Players: 10, Sum Players post PER: 136.71295174853645
# Year: 9, Count Players: 12, Sum Players post PER: 144.02038124445545
# Year: 4, Count Players: 11, Sum Players post PER: 0.0
# Year: 5, Count Players: 15, Sum Players post PER: 0.0
# Year: 10, Count Players: 9, Sum Players post PER: 120.14170843045451
# ---
# Team: CHA
# Year: 2, Count Players: 12, Sum Players post PER: 70.40877769976859
# Year: 3, Count Players: 13, Sum Players post PER: 43.07589210117629
# Year: 5, Count Players: 14, Sum Players post PER: 0.0
# Year: 1, Count Players: 13, Sum Players post PER: 0.0
# Year: 7, Count Players: 12, Sum Players post PER: 0.0
# Year: 4, Count Players: 11, Sum Players post PER: 110.78940043434098
# Year: 6, Count Players: 16, Sum Players post PER: 0.0
# ---
# Team: CLE
# Year: 1, Count Players: 13, Sum Players post PER: 164.26942355812457
# Year: 2, Count Players: 15, Sum Players post PER: 79.44247102909347
# Year: 3, Count Players: 13, Sum Players post PER: 0.0
# Year: 4, Count Players: 11, Sum Players post PER: 122.66718628021947
# ---
# Team: MIA
# Year: 1, Count Players: 13, Sum Players post PER: 0.0
# Year: 2, Count Players: 12, Sum Players post PER: 115.37550912663193
# Year: 3, Count Players: 15, Sum Players post PER: 0.0
# ---
# Team: LAS
# Year: 3, Count Players: 13, Sum Players post PER: 165.52931259515577
# Year: 8, Count Players: 15, Sum Players post PER: 0.0
# Year: 9, Count Players: 15, Sum Players post PER: 110.84039005789576
# Year: 10, Count Players: 11, Sum Players post PER: 103.17815294481318
# Year: 2, Count Players: 11, Sum Players post PER: 92.86042157744836
# Year: 4, Count Players: 15, Sum Players post PER: 87.72188858492822
# Year: 5, Count Players: 13, Sum Players post PER: 27.553278904057066
# Year: 6, Count Players: 14, Sum Players post PER: 80.51105318566896
# Year: 7, Count Players: 14, Sum Players post PER: 113.6167966776575
# Year: 1, Count Players: 11, Sum Players post PER: 137.35674374883962
# ---
# Team: IND
# Year: 7, Count Players: 12, Sum Players post PER: 69.2937101707936
# Year: 4, Count Players: 13, Sum Players post PER: 0.0
# Year: 9, Count Players: 15, Sum Players post PER: 55.42144925510292
# Year: 8, Count Players: 12, Sum Players post PER: 99.8169227162463
# Year: 6, Count Players: 12, Sum Players post PER: 73.42703903501891
# Year: 10, Count Players: 14, Sum Players post PER: 111.3087365359934
# Year: 2, Count Players: 13, Sum Players post PER: 0.0
# Year: 5, Count Players: 12, Sum Players post PER: 0.0
# Year: 3, Count Players: 13, Sum Players post PER: 111.9327826428671
# Year: 1, Count Players: 15, Sum Players post PER: 0.0
# ---
# Team: DET
# Year: 10, Count Players: 18, Sum Players post PER: 138.90527064821677
# Year: 7, Count Players: 13, Sum Players post PER: 85.80418410101392
# Year: 2, Count Players: 12, Sum Players post PER: 0.0
# Year: 6, Count Players: 15, Sum Players post PER: 67.48441899640963
# Year: 8, Count Players: 14, Sum Players post PER: 131.98394624495478
# Year: 9, Count Players: 19, Sum Players post PER: 104.36238789805898
# Year: 1, Count Players: 13, Sum Players post PER: 0.0
# Year: 3, Count Players: 15, Sum Players post PER: 0.0
# Year: 5, Count Players: 15, Sum Players post PER: 88.85352508729555
# Year: 4, Count Players: 13, Sum Players post PER: 98.75236624936795
# ---
# Team: ATL
# Year: 9, Count Players: 14, Sum Players post PER: 0.0
# Year: 10, Count Players: 13, Sum Players post PER: 97.35981123071078
# ---
# Team: POR
# Year: 2, Count Players: 13, Sum Players post PER: 0.0
# Year: 3, Count Players: 13, Sum Players post PER: 0.0
# Year: 1, Count Players: 12, Sum Players post PER: 0.0
# ---
# Team: PHO
# Year: 3, Count Players: 15, Sum Players post PER: 0.0
# Year: 10, Count Players: 12, Sum Players post PER: 167.65351759166947
# Year: 1, Count Players: 14, Sum Players post PER: 76.08383489900476
# Year: 4, Count Players: 21, Sum Players post PER: 0.0
# Year: 5, Count Players: 14, Sum Players post PER: 0.0
# Year: 6, Count Players: 15, Sum Players post PER: 0.0
# Year: 7, Count Players: 16, Sum Players post PER: 0.0
# Year: 2, Count Players: 18, Sum Players post PER: 0.0
# Year: 9, Count Players: 14, Sum Players post PER: 0.0
# Year: 8, Count Players: 13, Sum Players post PER: 97.88374687536447
# ---
# Team: CHI
# Year: 7, Count Players: 15, Sum Players post PER: 0.0
# Year: 8, Count Players: 14, Sum Players post PER: 0.0
# Year: 9, Count Players: 13, Sum Players post PER: 0.0
# Year: 10, Count Players: 12, Sum Players post PER: 0.0
# ---

# %% [markdown]
# ### Creating the final dataset

# %%
import pandas as pd

# Create a list to store the rows for teams_final
teams_final_rows = []

# Iterate through each team in dict_PowerRanking
for team, data_list in dict_PowerRanking.items():
    for data in data_list:
        year, count_players, sum_playersRanking = data

        # Get corresponding data from other dictionaries
        sum_PER = next((item[2] for item in dict_PER.get(team, []) if item[0] == year), 0.0)
        sum_postPowerRanking = next((item[2] for item in dict_postPowerRanking.get(team, []) if item[0] == year), 0.0)
        sum_postPER = next((item[2] for item in dict_postPER.get(team, []) if item[0] == year), 0.0)

        # Calculate averages
        avg_powerRanking = sum_playersRanking / count_players
        avg_PER = sum_PER / count_players
        avg_postPowerRanking = sum_postPowerRanking / count_players
        avg_postPER = sum_postPER / count_players

        # Append the row to the list
        teams_final_rows.append([team, year, avg_powerRanking, avg_PER, avg_postPowerRanking, avg_postPER])

# Create teams_final DataFrame
teams_final = pd.DataFrame(teams_final_rows, columns=['tmID', 'year', 'average_powerRanking', 'average_PER', 'average_postPowerRanking', 'average_postPER'])

# Display the resulting DataFrame
print(teams_final)

# Save to CSV
teams_final.to_csv('final_teams.csv', index=False)
# Out:
#     tmID  year  average_powerRanking  average_PER  average_postPowerRanking  \
# 0    MIN     2             30.047190     8.479390                  0.000000
# 1    MIN     3             26.264910     7.246348                  0.000000
# 2    MIN     4             29.079162     9.942765                 17.693188
# 3    MIN     5             27.563406     8.950899                 13.993237
# 4    MIN     6             24.014149     5.402515                  0.000000
# ..   ...   ...                   ...          ...                       ...
# 137  PHO     8             30.942955    11.302779                 24.331518
# 138  CHI     7             27.726301     8.537364                  0.000000
# 139  CHI     8             28.847562     9.830823                  0.000000
# 140  CHI     9             29.013699     7.481467                  0.000000
# 141  CHI    10             33.207864    11.654672                  0.000000
#
#      average_postPER
# 0           0.000000
# 1           0.000000
# 2           5.237931
# 3          -7.761160
# 4           0.000000
# ..               ...
# 137         7.529519
# 138         0.000000
# 139         0.000000
# 140         0.000000
# 141         0.000000
#
# [142 rows x 6 columns]
